# %%
text="""thon is
 a great
 programming
 language."""

print(text)
# Out:
# thon is
#  a great
#  programming
#  language.

# %%
text="yolda giderken\"hey\"sesini duydum"
print(text)
path=r"C:\Users\Hp\OneDrive\Desktop\pytonTest\.gitignore"
print(path)
# Out:
# yolda giderken"hey"sesini duydum
# C:\Users\Hp\OneDrive\Desktop\pytonTest\.gitignore

# %%
text="python"
harf=text[2]
print(harf)

# %%
text="python çok kolay bir dil"
kelime=text[7:10]
print(kelime)

# %% [markdown]
# pytonda hiçli k sıfırdır...
# -1 anlamı sağdan sola doğru oku demektir indeks için

# %%
text="python çok kolay bir dil"
text=text[::-1][::2]
print(text[::-2])
# Out:
# ldrbylkkçnhy

# %%
char='ali'
print(char*10)
# Out:
# alialialialialialialialialiali

# %%
name1='ali'
name2='veli'
name3='handan'
cumle="eve geldi"
names=[name1,name2,name3]
#Ali, Veli ve Handan eve geldi.
text=','.join(names)
print(text+" "+cumle)
# Out:
# ali,veli,handan

# %% [markdown]
# String Metodları

# %%
text="yeni metod"
text.upper()
text.title()
text.swapcase()

# %% [markdown]
# 6.Arama ve Kontrol
#
# ### a) find(substring)
# bazı hatalar kod yazılırken görülür...

# %%
text="python çok rahat öğrenilri"
print(text.find("çok"))
# Out:
# 7

# %%
text="python çok rahat öğrenil diyen nanayi yesin"
print(text.index("çok"))
# Out:
# 7

# %%
text="python çok rahat öğrenil diyen nanayi yesin"
print(text.count("p"))
# Out:
# 1

# %% [markdown]
# # split(seperator):## join()

# %%
text="Bugün hava çok soğuk ."

print(text.split(" ")) 
#text="Bugün hava çok soğuk ."
# Out:
# ['Bugün', 'hava', 'çok', 'soğuk', '.']

# %% [markdown]
# # FORMATLAMALAR

# %%
text1="Ayse"
text2="Ali"
print("{} ve {} bugün buluşacak".format(text1,text2))

# %%
name1='ali'
name2='veli'
print(f"Hosgeldin {name1}, {name2}")
# Out:
# Hosgeldin ali, veli

# %%
yas=20
ehliyet=True
if yas>=18:
    if ehliyet:
        print("Ehliyetiniz var, araba kullanabilirsiniz.")
    else:
        print("Ehliyetiniz yok, araba kullanamazsınız.")
